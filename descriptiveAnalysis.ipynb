# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
df = pd.read_csv("airline_passenger_satisfaction.csv")

# %%
df.shape
# Out:
# (129880, 24)

# %%
df.head()
# Out:
#    Unnamed: 0  Gender      customer_type  age   type_of_travel customer_class  \
# 0           0    Male     Loyal Customer   13  Personal Travel       Eco Plus
# 1           1    Male  disloyal Customer   25  Business travel       Business
# 2           2  Female     Loyal Customer   26  Business travel       Business
# 3           3  Female     Loyal Customer   25  Business travel       Business
# 4           4    Male     Loyal Customer   61  Business travel       Business
#
#    flight_distance  inflight_wifi_service  departure_arrival_time_convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                             int64
# Gender                                object
# customer_type                         object
# age                                    int64
# type_of_travel                        object
# customer_class                        object
# flight_distance                        int64
# inflight_wifi_service                  int64
# departure_arrival_time_convenient      int64
# ease_of_online_booking                 int64
# gate_location                          int64
# food_and_drink                         int64
# online_boarding                        int64
# seat_comfort                           int64
# inflight_entertainment                 int64
# onboard_service                        int64
# leg_room_service                       int64
# baggage_handling                       int64
# checkin_service                        int64
# inflight_service                       int64
# cleanliness                            int64
# ...

# %%
data = df.drop('Unnamed: 0', axis=1)

# %%
# split into train test sets
train, test = train_test_split(data,test_size=0.2,random_state= 20)

# %%
train.shape
# Out:
# (103904, 23)

# %%
train.head()
# Out:
#         Gender      customer_type  age   type_of_travel customer_class  \
# 62212   Female     Loyal Customer   39  Business travel       Business
# 69250     Male     Loyal Customer   49  Business travel       Business
# 21132   Female     Loyal Customer   64  Personal Travel            Eco
# 120003  Female     Loyal Customer   48  Business travel       Business
# 68495     Male  disloyal Customer   33  Business travel            Eco
#
#         flight_distance  inflight_wifi_service  \
# 62212              3624                      1
# 69250              3536                      2
# 21132               308                      2
# 120003             1428                      2
# 68495               554                      1
#
#         departure_arrival_time_convenient  ease_of_online_booking  \
# 62212                                   3                       1
# 69250                                   2                       2
# ...

# %%
train.isnull().sum()
# Out:
# Gender                                 0
# customer_type                          0
# age                                    0
# type_of_travel                         0
# customer_class                         0
# flight_distance                        0
# inflight_wifi_service                  0
# departure_arrival_time_convenient      0
# ease_of_online_booking                 0
# gate_location                          0
# food_and_drink                         0
# online_boarding                        0
# seat_comfort                           0
# inflight_entertainment                 0
# onboard_service                        0
# leg_room_service                       0
# baggage_handling                       0
# checkin_service                        0
# inflight_service                       0
# cleanliness                            0
# departure_delay_in_minutes             0
# arrival_delay_in_minutes             318
# satisfaction                           0
# ...

# %%
train['arrival_delay_in_minutes'].fillna(0, inplace = True)
# Out:
# C:\Users\thanu\anaconda3\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
train.isnull().sum()
# Out:
# Gender                               0
# customer_type                        0
# age                                  0
# type_of_travel                       0
# customer_class                       0
# flight_distance                      0
# inflight_wifi_service                0
# departure_arrival_time_convenient    0
# ease_of_online_booking               0
# gate_location                        0
# food_and_drink                       0
# online_boarding                      0
# seat_comfort                         0
# inflight_entertainment               0
# onboard_service                      0
# leg_room_service                     0
# baggage_handling                     0
# checkin_service                      0
# inflight_service                     0
# cleanliness                          0
# departure_delay_in_minutes           0
# arrival_delay_in_minutes             0
# satisfaction                         0
# dtype: int64

# %%
cols =['inflight_wifi_service','departure_arrival_time_convenient','ease_of_online_booking','gate_location','food_and_drink','online_boarding','seat_comfort','inflight_entertainment','onboard_service','leg_room_service','baggage_handling','checkin_service','inflight_service','cleanliness']
for col in cols:
    train.loc[:,col] = train.loc[:,col].astype('object')
# Out:
# C:\Users\thanu\anaconda3\lib\site-packages\pandas\core\indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
train.dtypes
# Out:
# Gender                                object
# customer_type                         object
# age                                    int64
# type_of_travel                        object
# customer_class                        object
# flight_distance                        int64
# inflight_wifi_service                 object
# departure_arrival_time_convenient     object
# ease_of_online_booking                object
# gate_location                         object
# food_and_drink                        object
# online_boarding                       object
# seat_comfort                          object
# inflight_entertainment                object
# onboard_service                       object
# leg_room_service                      object
# baggage_handling                      object
# checkin_service                       object
# inflight_service                      object
# cleanliness                           object
# departure_delay_in_minutes             int64
# ...

# %%
numerical_features = data.select_dtypes(include=np.number).columns.to_list()
numerical_features
# Out:
# ['age',
#  'flight_distance',
#  'inflight_wifi_service',
#  'departure_arrival_time_convenient',
#  'ease_of_online_booking',
#  'gate_location',
#  'food_and_drink',
#  'online_boarding',
#  'seat_comfort',
#  'inflight_entertainment',
#  'onboard_service',
#  'leg_room_service',
#  'baggage_handling',
#  'checkin_service',
#  'inflight_service',
#  'cleanliness',
#  'departure_delay_in_minutes',
#  'arrival_delay_in_minutes']

# %%
categorical_features = data.select_dtypes(exclude=np.number).columns.to_list()
categorical_features
# Out:
# ['Gender', 'customer_type', 'type_of_travel', 'customer_class', 'satisfaction']

# %% [markdown]
# Univariate analysis

# %%
sns.set_palette("rainbow")
sns.countplot(x ='Gender', data = train)
plt.title("DIstributuion of gender")
plt.show()

# %%
sns.boxplot(x=train['age'])
plt.title('Distribution of age')
plt.show()

# %%
sns.countplot(x ='type_of_travel', data = train)
plt.title("DIstributuion of type_of_travel")
plt.show()

# %%
sns.countplot(x ='customer_class', data = train)
plt.title("DIstributuion of customer_class")
plt.show()

# %% [markdown]
# # Dependent variable(satisfaction) vs. Independent variables

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# %% [markdown]
# Gender vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='Gender', data=train)
plt.title('Count plot for Gender')
plt.show()

# %% [markdown]
# customer_type Vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='customer_type', data=train)
plt.title('Count plot for customer_type')
plt.show()

# %% [markdown]
# type_of_travel Vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='type_of_travel', data=train)
plt.title('Count plot for type_of_travel')
plt.show()

# %% [markdown]
# customer_class Vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='customer_class', data=train)
plt.title('Count plot for customer_class')
plt.show()

# %% [markdown]
# inflight_wifi_service Vs. satisfaction

# %%
ax = sns.countplot(x='inflight_wifi_service', hue='satisfaction', data=train)
plt.title('Count plot for inflight_wifi_service')
plt.show()

# %%
ax = sns.countplot(x='satisfaction', hue='inflight_wifi_service', data=train)
plt.title('Count plot for inflight_wifi_service')
plt.show()

# %% [markdown]
# departure_arrival_time_convenient vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='departure_arrival_time_convenient', data=train)
plt.title('Count plot for departure_arrival_time_convenient')
plt.show()

# %% [markdown]
# ease_of_online_booking vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='ease_of_online_booking', data=train)
plt.title('Count plot for ease_of_online_booking')
plt.show()

# %% [markdown]
# gate_location vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='gate_location', data=train)
plt.title('Count plot for gate_location')
plt.show()

# %% [markdown]
# food_and_drink vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='food_and_drink', data=train)
plt.title('Count plot for food_and_drink')
plt.show()

# %% [markdown]
# online_boarding vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='online_boarding', data=train)
plt.title('Count plot for online_boarding')
plt.show()

# %% [markdown]
# seat_comfort vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='seat_comfort', data=train)
plt.title('Count plot for seat_comfort')
plt.show()

# %% [markdown]
# inflight_entertainment vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='inflight_entertainment', data=train)
plt.title('Count plot for inflight_entertainment')
plt.show()

# %% [markdown]
# onboard_service vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='onboard_service', data=train)
plt.title('Count plot for onboard_service')
plt.show()

# %% [markdown]
# leg_room_service vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='leg_room_service', data=train)
plt.title('Count plot for leg_room_service')
plt.show()

# %% [markdown]
# baggage_handling vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='baggage_handling', data=train)
plt.title('Count plot for baggage_handling')
plt.show()

# %% [markdown]
# checkin_service vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='checkin_service', data=train)
plt.title('Count plot for checkin_service')
plt.show()

# %% [markdown]
# inflight_service vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='inflight_service', data=train)
plt.title('Count plot for inflight_service')
plt.show()

# %% [markdown]
# cleanliness vs. satisfaction

# %%
ax = sns.countplot(x='satisfaction', hue='cleanliness', data=train)
plt.title('Count plot for cleanliness')
plt.show()

# %% [markdown]
# flight_distance vs. satisfaction

# %%
sns.boxplot(x="satisfaction",
                y="flight_distance",
                data=train, orient='v' )
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='flight_distance'>

# %%
sns.displot(data=train, x='flight_distance', kind='kde', hue='satisfaction')

# %% [markdown]
# age vs. satisfaction

# %%
sns.boxplot(x="satisfaction",
                y="age",
                data=train, orient='v' )
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='age'>

# %%
sns.displot(data=train, x='age', kind='kde', hue='satisfaction')

# %% [markdown]
# departure_delay_in_minutes vs. satisfaction

# %%
sns.boxplot(x="satisfaction",
                y="departure_delay_in_minutes",
                data=train, orient='v' )
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='departure_delay_in_minutes'>

# %%
sns.displot(data=train, x='departure_delay_in_minutes', kind='kde', hue='satisfaction')

# %%
sns.stripplot(x="satisfaction",
                y="departure_delay_in_minutes",
                data=train, jitter = True )
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='departure_delay_in_minutes'>

# %% [markdown]
# arrival_delay_in_minutes vs. satisfaction

# %%
sns.boxplot(x="satisfaction",
                y="arrival_delay_in_minutes",
                data=train, orient='v' )
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='arrival_delay_in_minutes'>

# %%
sns.stripplot(x="satisfaction",
                y="arrival_delay_in_minutes",
                data=train, jitter = True )
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='arrival_delay_in_minutes'>

# %% [markdown]
# arrival_delay_in_minutes,departure_delay_in_minutes vs. satisfaction

# %%
sns.lmplot(x='arrival_delay_in_minutes',y='departure_delay_in_minutes',data = train,hue = 'satisfaction',col='satisfaction')

# %%
sns.lmplot(x='flight_distance',y='departure_delay_in_minutes',data = train,hue = 'satisfaction',col='satisfaction')

# %%
sns.countplot(x='type_of_travel', hue='customer_class', data=train)
# Out:
# <AxesSubplot:xlabel='type_of_travel', ylabel='count'>

# %%
sns.boxplot(x="Gender",
                y="age",
                data=train, orient='v' )
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='age'>

# %%
sns.countplot(x='customer_type', hue='Gender', data=train)
# Out:
# <AxesSubplot:xlabel='customer_type', ylabel='count'>

# %%
sns.countplot(x='type_of_travel', hue='Gender', data=train)
# Out:
# <AxesSubplot:xlabel='type_of_travel', ylabel='count'>

# %%
sns.countplot(x='Gender', hue='cleanliness', data=train)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.displot(data=train, x='age', kind='kde', hue='Gender')

# %%
sns.boxplot(x="Gender",
                y="flight_distance",
                data=train, orient='v' )
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='flight_distance'>

# %%
sns.displot(data=train, x='flight_distance', kind='kde', hue='Gender')
